# %% [markdown]
# # Matplotlib

# %%
import matplotlib as mlp
print(mlp.__version__)
# Out:
# 3.5.2

# %% [markdown]
# functions  --> pyplot

# %% [markdown]
# import matplotlib.pyplot as plt
# print(plt.__version__)

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0,6,20])
y = np.array([0,100,200])

plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0,6,20])
y = np.array([0,100,200])

plt.plot(x,y,'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0,6,20])
y = np.array([0,100,200])

plt.plot(x,y,"*")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0,6,20])
y = np.array([0,100,200])

plt.plot(x,y,"s") # square
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0,6,20,4,7,23])
#y = np.array([0,100,200])

plt.plot(x)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#x = np.array([0,6,20])
y = np.array([3,6,9,10,4,2,6])

plt.plot(y,"s")
plt.show()

# %% [markdown]
# # use marker

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0,6,20,4,7,23])
#y = np.array([0,100,200])

plt.plot(x,marker="s")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0,6,20,4,7,23])
#y = np.array([0,100,200])

plt.plot(x,marker="p") # pentagan symble
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0,6,20,4,7,23])
#y = np.array([0,100,200])

plt.plot(x,marker="P")  # plus symble
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0,6,20,4,7,23])
#y = np.array([0,100,200])

plt.plot(x,marker="d") # diamond
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0,6,20,4,7,23])
#y = np.array([0,100,200])

plt.plot(x,marker="h") # hexagonal
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0,6,20,4,7,23])
#y = np.array([0,100,200])

plt.plot(x,marker="3")
plt.show()

# %% [markdown]
# # color changing

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0,6,20,4,7,23])
#y = np.array([0,100,200])

plt.plot(x,"s:r")   # to change the color into red
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0,6,20,4,7,23])
#y = np.array([0,100,200])

plt.plot(x,"s:g") # green
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0,6,20,4,7,23])
#y = np.array([0,100,200])

plt.plot(x,"*:b")  #bold star
plt.show()

# %% [markdown]
# # use solid lines

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0,6,20,4,7,23])
#y = np.array([0,100,200])

plt.plot(x,"s-r")  # solid line, red
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0,6,20,4,7,23])
#y = np.array([0,100,200])

plt.plot(x,"*-b")
plt.show()

# %% [markdown]
# colon : ---> dotted lines
#
# hiphen -  ---> solid lines

# %% [markdown]
# # use double hiphens

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0,6,20,4,7,23])
#y = np.array([0,100,200])

plt.plot(x,"s--g") # double dash
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0,6,20,4,7,23])
#y = np.array([0,100,200])

plt.plot(x,"*-.b")  # hiphen and dot ( -.)
plt.show()

# %% [markdown]
# # increase marker size

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0,6,20,4,7,23])
#y = np.array([0,100,200])

plt.plot(x,marker="o",ms=20)  # ms --> marker size
plt.show()

# %% [markdown]
# # change marker color

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0,6,20,4,7,23])
#y = np.array([0,100,200])

plt.plot(x,marker="o",ms=30, mec="r")  # mec="r"   -->outside the marker red color
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0,6,20,4,7,23])
#y = np.array([0,100,200])

plt.plot(x,marker="o",ms=30, mfc="r")  # mfc="r"   --> inside the marker red color
plt.show()

# %% [markdown]
# here we use hexa-decimal colors also

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0,6,20,4,7,23])
#y = np.array([0,100,200])

plt.plot(x,marker="o",ms=30, mec="r",mfc="y")  # mec="r"   -->outside the marker   mfc="y" ---> inside the marker
plt.show()

# %% [markdown]
# # line styles function

# %% [markdown]
# linestyle="dotted" or "dashed"

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0,6,20,4,7,23])
#y = np.array([0,100,200])

plt.plot(x,linestyle="dotted")   # dotted line
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0,6,20,4,7,23])
#y = np.array([0,100,200])

plt.plot(x,linestyle="dashed")  # dashed lines
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0,6,20,4,7,23])
#y = np.array([0,100,200])

plt.plot(x,ls="dotted")  # use   --> ls func
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0,6,20,4,7,23])
#y = np.array([0,100,200])

plt.plot(x,ls="--")  # use   --> ls func
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0,6,20,4,7,23])
#y = np.array([0,100,200])

plt.plot(x,ls="-.")  # use   --> ls func
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0,6,20,4,7,23])
#y = np.array([0,100,200])

plt.plot(x,ls="-.",color="g")  # to change the colors also  
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0,6,20,4,7,23])
#y = np.array([0,100,200])

plt.plot(x,ls="-.",color="y")  # to change the colors also  
plt.show()

# %% [markdown]
# # line thickness --> use linewidth func

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0,6,20,4,7,23])
# = np.array([0,30,23,45,67])

plt.plot(x,linewidth=10)  # to change the colors also  
plt.show()

# %% [markdown]
# # use 2 lines in same graph

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0,6,20,4,7,23])
x1 = np.array([0,30,23,45,67])

plt.plot(x,linewidth=10)
plt.plot(x1,linewidth=7)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0,6,20,4,7,23])
x1 = np.array([0,30,23,45,67,51])

plt.plot(x,x1)  
plt.show()

# %% [markdown]
# # gives a title here

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0,6,20,33,46,59])
x1 = np.array([11,39,42,60,81,83])

plt.plot(x,x1)
plt.title("sample plots")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0,6,20,33,46,59])
y = np.array([11,39,42,60,81,83])

plt.plot(x,y)
plt.title("x and y plot")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.show()

# %% [markdown]
# # use grid

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0,6,20,33,46,59])
y = np.array([11,39,42,60,81,83])

plt.plot(x,y)
plt.title("x and y plot")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0,6,20,33,46,59])
y = np.array([11,39,42,60,81,83])

plt.plot(x,y)
plt.title("x and y plot")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.grid(axis="x")    # to show only x-axis
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0,6,20,33,46,59])
y = np.array([11,39,42,60,81,83])

plt.plot(x,y)
plt.title("x and y plot")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.grid(axis="y")    # to show only y-axis
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0,6,20,33,46,59])
y = np.array([11,39,42,60,81,83])

plt.plot(x,y)
plt.title("x and y plot")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.grid(axis="x",color="r")    # to show only x-axis, and change grid color="red"
plt.show()

# %% [markdown]
# # subplot()  ---> 2 plots

# %%
import matplotlib.pyplot as plt
import numpy as np

# plot 1
x = np.array([0,6,20,33,46,59])
y = np.array([11,39,42,60,81,83])
plt.subplot(1,2,1)   # use ----> subplot()   | (1,2,1) --> 1st row, 2nd column, 1st plot
plt.plot(x,y)


# plot 2
x = np.array([1,4,6,8,23,33])
y = np.array([0,22,40,46,55,67]) 
plt.subplot(1,2,1)   # use ----> subplot()     | 1,2,1) --> 1st row, 2nd column, 1st plot
plt.plot(x,y)


plt.title("x and y plot")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.grid(axis="x")    # to show only x-axis
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# plot 1
x = np.array([0,6,20,33,46,59])
y = np.array([11,39,42,60,81,83])
plt.subplot(1,2,1)   # use ----> subplot()   | (1,2,1) --> 1st row, 2nd column, 1st plot
plt.plot(x,y)


# plot 2
x = np.array([1,4,6,8,23,33])
y = np.array([0,22,40,46,55,67]) 
plt.subplot(1,2,2)   # use ----> subplot()     | 1,2,2) --> 1st row, 2nd column, 2nd plot
plt.plot(x,y)


plt.title("x and y plot")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.grid(axis="x")    # to show only x-axis
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# plot 1
x = np.array([0,6,20,33,46,59])
y = np.array([11,39,42,60,81,83])
plt.subplot(2,1,1)   # use ----> subplot()   | (1,2,1) --> 2 row, 1 column, 1st plot
plt.plot(x,y)


# plot 2
x = np.array([1,4,6,8,23,33])
y = np.array([0,22,40,46,55,67]) 
plt.subplot(2,1,2)   # use ----> subplot()     | 1,2,2) --> 2 row, 1 column, 2nd plot
plt.plot(x,y)


plt.title("x and y plot")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.grid(axis="x")    # to show only x-axis
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# plot 1
x = np.array([0,6,20,33,46,59])
y = np.array([11,39,42,60,81,83])
plt.subplot(2,1,2)   # use ----> subplot()   | (1,2,1) --> 2 row, 1 column, 1st plot
plt.plot(x,y)


# plot 2
x = np.array([1,4,6,8,23,33])
y = np.array([0,22,40,46,55,67]) 
plt.subplot(2,1,1)   # use ----> subplot()     | 1,2,2) --> 2 row, 1 column, 2nd plot
plt.plot(x,y)


plt.title("x and y plot")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.grid(axis="y",color="r")    # to show only x-axis
plt.suptitle("for matplotlib course")                                    # super title

plt.show()

# %%
bar chart

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0,6,20,33,46,59])
y = np.array([11,39,42,60,81,83])

plt.bar(x,y)
plt.show()

# %% [markdown]
# # coloring

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0,6,20,33,46,59])
y = np.array([11,39,42,60,81,83])

plt.bar(x,y,color="r")
plt.show()

# %% [markdown]
# # histogram

# %%
# histogram

import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(160,10,250)
print(x)

plt.hist(x)
plt.show()
# Out:
# [157.03129779 156.23851463 150.80820592 160.10765133 149.82057108
#  167.42361409 169.90589097 149.29179609 160.42783834 159.25587557
#  169.61407131 168.99717968 163.77628858 166.68143512 160.41587926
#  140.43334481 147.82645957 152.67168022 154.79782365 157.76683577
#  173.4008251  162.27209268 175.39398418 148.11462777 169.73842378
#  157.87956852 172.09458601 159.55806017 156.14345992 176.95968501
#  165.4279633  170.33334555 162.8794047  167.83191909 167.49508316
#  166.65666832 163.09420597 160.54642043 165.72265258 173.61390916
#  147.93714378 188.90119585 145.00198527 166.34749632 161.48061314
#  152.45472752 164.8416698  162.30342735 150.32923419 154.86618403
#  178.02847525 157.04133133 155.41032945 163.66366039 173.40877271
#  167.99751818 146.74910923 153.20436093 165.26702824 173.39398848
#  168.1995969  161.3736615  174.42439487 163.21899752 175.58579278
#  169.01404694 167.51517148 154.94255295 144.10738868 160.53915962
# ...

# %% [markdown]
# # pie chart

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0,6,20,33,46,59])


plt.pie(x)
plt.show()

# %% [markdown]
# always positive x axis is starting value.

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([6,20,33,46,59])
mylabel=["apple","green apple","orange","guava","grapes"]

plt.pie(x,labels=mylabel)     # labels 
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([6,20,33,46,59])
mylabel=["apple","green apple","orange","guava","grapes"]

plt.pie(x,labels=mylabel,startangle=90)     # labels 
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([6,20,33,46,59])
mylabel=["apple","green apple","orange","guava","grapes"]

plt.pie(x,labels=mylabel,startangle=180)     # labels 
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([6,20,33,46,59])
mylabel=["apple","green apple","orange","guava","grapes"]
separate=[0,0.1,0.2,0,0.1]

plt.pie(x,labels=mylabel,explode=separate)     # expode=separate
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([6,20,33,46,59])
mylabel=["apple","green apple","orange","guava","grapes"]
separate=[0,0.1,0.2,0,0.1]
mycolors=["red","black","green","blue","yellow"]

plt.pie(x,labels=mylabel,explode=separate,colors=mycolors)     # expode=separate
plt.show()
